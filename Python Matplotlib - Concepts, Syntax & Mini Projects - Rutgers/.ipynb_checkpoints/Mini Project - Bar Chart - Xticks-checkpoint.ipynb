# %%
# %matplotlib notebook
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
cities = ["New Orleans", "Milwaukee", "Omaha", "Pittsburgh", "Toledo"]
bars_in_cities = [8.6, 8.5, 8.3, 7.9, 7.2]

# %%
x_axis = np.arange(len(bars_in_cities))

# %%
x_axis
# Out:
# array([0, 1, 2, 3, 4])

# %%
# Create a bar chart based upon the above data
plt.bar(x_axis, bars_in_cities,color="blue")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 5 artists>

# %%
# Create the ticks for our bar chart's x axis
xticks = [x for x in x_axis]
xticks
# Out:
# [0, 1, 2, 3, 4]

# %%
plt.xticks(xticks, cities)
# Out:
# ([<matplotlib.axis.XTick at 0x1f64a80f2b0>,
#   <matplotlib.axis.XTick at 0x1f64a80aba8>,
#   <matplotlib.axis.XTick at 0x1f64a82ff98>,
#   <matplotlib.axis.XTick at 0x1f64a839898>,
#   <matplotlib.axis.XTick at 0x1f64a839e80>],
#  <a list of 5 Text xticklabel objects>)

# %%
# Set the limits of the y axis
plt.ylim(0,9)
# Out:
# (0, 9)

# %%
# Give the chart a title, x label, and y label
plt.title("Density of Bars in Cities")
plt.xlabel("Cities")
plt.ylabel("Bars per 10,000 Households")
# Out:
# Text(104.729,0.5,'Bars per 10,000 Households')

# %%
# Save an image of the chart and print it to the screen
plt.savefig("BarsInCities.jpg")

# %% [markdown]
# # Get Other Tweets
#
# * In this activity, we will retrieve tweets sent out by any account of our choosing!
#
# ## Instructions
#
# * Choose a twitter account and save the screen name to a variable.
#
# * Retrieve the latest tweets sent out from that account.
#
# * Use the code from the previous activities to get you started!
#
# * Consult the [Tweepy Docs](http://docs.tweepy.org/en/v3.5.0/api.html) as needed.

# %%
# Dependencies
import tweepy
import json
from pprint import pprint

# %%
from config import consumer_key, consumer_secret, access_token, access_token_secret

# %%
# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target User
target_user = "MonikerAsh"

# %%
# Get all tweets from home feed
Othertweets = api.user_timeline(target_user)

# %%
# Loop through all tweets
for tweets in Othertweets:
    pprint(tweets)
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Wed Feb 13 22:17:32 +0000 2019',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 18997933,
#                                  'id_str': '18997933',
#                                  'indices': [0, 16],
#                                  'name': 'Paula Poundstone',
#                                  'screen_name': 'paulapoundstone'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1095809224058306560,
#  'id_str': '1095809224058306560',
#  'in_reply_to_screen_name': 'paulapoundstone',
#  'in_reply_to_status_id': 1075903044674441217,
#  'in_reply_to_status_id_str': '1075903044674441217',
#  'in_reply_to_user_id': 18997933,
#  'in_reply_to_user_id_str': '18997933',
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/iphone" '
#            'rel="nofollow">Twitter for iPhone</a>',
#  'text': '@paulapoundstone I see your point but I would also count on the '
#          'sanity of rest of GOP - but wait where are they?',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sun May 17 03:22:39 +0000 2009',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': 'I lead teams away from information hoarding on a '
#                          'path of data interpretation & analyitcs BIG Data '
#                          'style!',
#           'entities': {'description': {'urls': []}},
#           'favourites_count': 5,
#           'follow_request_sent': False,
#           'followers_count': 18,
#           'following': True,
#           'friends_count': 35,
#           'geo_enabled': False,
#           'has_extended_profile': True,
#           'id': 40598976,
#           'id_str': '40598976',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 0,
#           'location': '',
#           'name': 'Ashish Nachane',
#           'notifications': False,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/40598976/1505523267',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'MonikerAsh',
#           'statuses_count': 77,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Dec 11 11:47:48 +0000 2018',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 5392522,
#                                  'id_str': '5392522',
#                                  'indices': [3, 7],
#                                  'name': 'NPR',
#                                  'screen_name': 'NPR'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1072457920611344386,
#  'id_str': '1072457920611344386',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'retweet_count': 711,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#                       'coordinates': None,
#                       'created_at': 'Mon Dec 10 15:49:38 +0000 2018',
#                       'entities': {'hashtags': [],
#                                    'symbols': [],
#                                    'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#                                              'expanded_url': 'https://twitter.com/i/web/status/1072156391471833088',
#                                              'indices': [117, 140],
#                                              'url': 'https://t.co/e7ZSGwro0M'}],
#                                    'user_mentions': []},
#                       'favorite_count': 2031,
#                       'favorited': False,
#                       'geo': None,
#                       'id': 1072156391471833088,
#                       'id_str': '1072156391471833088',
#                       'in_reply_to_screen_name': None,
#                       'in_reply_to_status_id': None,
#                       'in_reply_to_status_id_str': None,
#                       'in_reply_to_user_id': None,
#                       'in_reply_to_user_id_str': None,
#                       'is_quote_status': False,
#                       'lang': 'en',
#                       'place': None,
#                       'retweet_count': 711,
#                       'retweeted': False,
#                       'source': '<a '
#                                 'href="https://about.twitter.com/products/tweetdeck" '
#                                 'rel="nofollow">TweetDeck</a>',
#                       'text': 'JUST IN: The U.S. Supreme Court declined to '
#                               'take a case with big implications for women’s '
#                               'health care, Planned Pare… '
#                               'https://t.co/e7ZSGwro0M',
#                       'truncated': True,
#                       'user': {'contributors_enabled': False,
#                                'created_at': 'Sun Apr 22 05:10:15 +0000 2007',
#                                'default_profile': False,
#                                'default_profile_image': False,
#                                'description': 'News. Arts & Life. Music. '
#                                               'Everything and more from NPR.\n'
#                                               '\n'
#                                               '🕵️ Securely send us news tips: '
#                                               'https://t.co/LPkf6Tsozm',
#                                'entities': {'description': {'urls': [{'display_url': 'securedrop.npr.org',
#                                                                       'expanded_url': 'http://securedrop.npr.org',
#                                                                       'indices': [88,
#                                                                                   111],
#                                                                       'url': 'https://t.co/LPkf6Tsozm'}]},
#                                             'url': {'urls': [{'display_url': 'npr.org',
#                                                               'expanded_url': 'http://www.npr.org',
#                                                               'indices': [0,
#                                                                           22],
#                                                               'url': 'http://t.co/SoL86ga4RI'}]}},
#                                'favourites_count': 2446,
#                                'follow_request_sent': False,
#                                'followers_count': 7685205,
#                                'following': False,
#                                'friends_count': 71217,
#                                'geo_enabled': False,
#                                'has_extended_profile': True,
#                                'id': 5392522,
#                                'id_str': '5392522',
#                                'is_translation_enabled': True,
#                                'is_translator': False,
#                                'lang': 'en',
#                                'listed_count': 66385,
#                                'location': '',
#                                'name': 'NPR',
#                                'notifications': False,
#                                'profile_background_color': '9AE4E8',
#                                'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#                                'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#                                'profile_background_tile': False,
#                                'profile_banner_url': 'https://pbs.twimg.com/profile_banners/5392522/1406560384',
#                                'profile_image_url': 'http://pbs.twimg.com/profile_images/722199003845304320/s2zwEoao_normal.jpg',
#                                'profile_image_url_https': 'https://pbs.twimg.com/profile_images/722199003845304320/s2zwEoao_normal.jpg',
#                                'profile_link_color': '0000FF',
#                                'profile_sidebar_border_color': '87BC44',
#                                'profile_sidebar_fill_color': 'E0FF92',
#                                'profile_text_color': '000000',
#                                'profile_use_background_image': True,
#                                'protected': False,
#                                'screen_name': 'NPR',
#                                'statuses_count': 170771,
#                                'time_zone': None,
#                                'translator_type': 'none',
#                                'url': 'http://t.co/SoL86ga4RI',
#                                'utc_offset': None,
#                                'verified': True}},
#  'source': '<a href="http://twitter.com/download/iphone" '
#            'rel="nofollow">Twitter for iPhone</a>',
#  'text': 'RT @NPR: JUST IN: The U.S. Supreme Court declined to take a case '
#          'with big implications for women’s health care, Planned Parenthood '
#          'and whet…',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sun May 17 03:22:39 +0000 2009',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': 'I lead teams away from information hoarding on a '
#                          'path of data interpretation & analyitcs BIG Data '
#                          'style!',
#           'entities': {'description': {'urls': []}},
#           'favourites_count': 5,
#           'follow_request_sent': False,
#           'followers_count': 18,
#           'following': True,
#           'friends_count': 35,
#           'geo_enabled': False,
#           'has_extended_profile': True,
#           'id': 40598976,
#           'id_str': '40598976',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 0,
#           'location': '',
#           'name': 'Ashish Nachane',
#           'notifications': False,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/40598976/1505523267',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'MonikerAsh',
#           'statuses_count': 77,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Dec 11 11:46:37 +0000 2018',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#                         'expanded_url': 'https://twitter.com/i/web/status/1072457623872659457',
#                         'indices': [117, 140],
#                         'url': 'https://t.co/xYWc4Ex3kK'}],
#               'user_mentions': [{'id': 18997933,
#                                  'id_str': '18997933',
#                                  'indices': [0, 16],
#                                  'name': 'Paula Poundstone',
#                                  'screen_name': 'paulapoundstone'}]},
#  'favorite_count': 1,
#  'favorited': False,
#  'geo': None,
#  'id': 1072457623872659457,
#  'id_str': '1072457623872659457',
#  'in_reply_to_screen_name': 'paulapoundstone',
#  'in_reply_to_status_id': 1071461076485767168,
#  'in_reply_to_status_id_str': '1071461076485767168',
#  'in_reply_to_user_id': 18997933,
#  'in_reply_to_user_id_str': '18997933',
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/iphone" '
#            'rel="nofollow">Twitter for iPhone</a>',
#  'text': '@paulapoundstone Paula I agree that’s like the athletes that are '
#          'stripped off their winnings once they admit to che… '
#          'https://t.co/xYWc4Ex3kK',
#  'truncated': True,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sun May 17 03:22:39 +0000 2009',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': 'I lead teams away from information hoarding on a '
#                          'path of data interpretation & analyitcs BIG Data '
#                          'style!',
#           'entities': {'description': {'urls': []}},
#           'favourites_count': 5,
#           'follow_request_sent': False,
#           'followers_count': 18,
#           'following': True,
#           'friends_count': 35,
#           'geo_enabled': False,
#           'has_extended_profile': True,
#           'id': 40598976,
#           'id_str': '40598976',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 0,
#           'location': '',
#           'name': 'Ashish Nachane',
#           'notifications': False,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/40598976/1505523267',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'MonikerAsh',
#           'statuses_count': 77,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Fri Dec 07 22:41:52 +0000 2018',
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1071172971270717440,
#  'id_str': '1071172971270717440',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/iphone" '
#            'rel="nofollow">Twitter for iPhone</a>',
#  'text': 'On my way to Wait Wait Don’t tell me live recording!',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sun May 17 03:22:39 +0000 2009',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': 'I lead teams away from information hoarding on a '
#                          'path of data interpretation & analyitcs BIG Data '
#                          'style!',
#           'entities': {'description': {'urls': []}},
#           'favourites_count': 5,
#           'follow_request_sent': False,
#           'followers_count': 18,
#           'following': True,
#           'friends_count': 35,
#           'geo_enabled': False,
#           'has_extended_profile': True,
#           'id': 40598976,
#           'id_str': '40598976',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 0,
#           'location': '',
#           'name': 'Ashish Nachane',
#           'notifications': False,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/40598976/1505523267',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'MonikerAsh',
#           'statuses_count': 77,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Fri Oct 26 21:59:41 +0000 2018',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 13784322,
#                                  'id_str': '13784322',
#                                  'indices': [0, 9],
#                                  'name': 'waitwait',
#                                  'screen_name': 'waitwait'},
#                                 {'id': 38218024,
#                                  'id_str': '38218024',
#                                  'indices': [10, 25],
#                                  'name': 'The Chicago Theatre',
#                                  'screen_name': 'ChicagoTheatre'},
#                                 {'id': 18997933,
#                                  'id_str': '18997933',
#                                  'indices': [52, 68],
#                                  'name': 'Paula Poundstone',
#                                  'screen_name': 'paulapoundstone'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1055942065752866816,
#  'id_str': '1055942065752866816',
#  'in_reply_to_screen_name': 'waitwait',
#  'in_reply_to_status_id': 1055481502773993473,
#  'in_reply_to_status_id_str': '1055481502773993473',
#  'in_reply_to_user_id': 13784322,
#  'in_reply_to_user_id_str': '13784322',
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/iphone" '
#            'rel="nofollow">Twitter for iPhone</a>',
#  'text': '@waitwait @ChicagoTheatre I am for any moment where @paulapoundstone '
#          'is full on!  May be most shows ..',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sun May 17 03:22:39 +0000 2009',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': 'I lead teams away from information hoarding on a '
#                          'path of data interpretation & analyitcs BIG Data '
#                          'style!',
#           'entities': {'description': {'urls': []}},
#           'favourites_count': 5,
#           'follow_request_sent': False,
#           'followers_count': 18,
#           'following': True,
#           'friends_count': 35,
#           'geo_enabled': False,
#           'has_extended_profile': True,
#           'id': 40598976,
#           'id_str': '40598976',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 0,
#           'location': '',
#           'name': 'Ashish Nachane',
#           'notifications': False,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/40598976/1505523267',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'MonikerAsh',
#           'statuses_count': 77,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Wed Oct 24 17:13:28 +0000 2018',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#                         'expanded_url': 'https://twitter.com/i/web/status/1055145261746544641',
#                         'indices': [116, 139],
#                         'url': 'https://t.co/H0M6CpXrbE'}],
#               'user_mentions': [{'id': 14985228,
#                                  'id_str': '14985228',
#                                  'indices': [0, 11],
#                                  'name': 'Peter Sagal',
#                                  'screen_name': 'petersagal'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1055145261746544641,
#  'id_str': '1055145261746544641',
#  'in_reply_to_screen_name': 'petersagal',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': 14985228,
#  'in_reply_to_user_id_str': '14985228',
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#  'text': '@petersagal I am so thrilled to have finally able to get tweeting '
#          'with you sir! I am a HUUUGGGEEE fan of WWDTM and… '
#          'https://t.co/H0M6CpXrbE',
#  'truncated': True,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sun May 17 03:22:39 +0000 2009',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': 'I lead teams away from information hoarding on a '
#                          'path of data interpretation & analyitcs BIG Data '
#                          'style!',
#           'entities': {'description': {'urls': []}},
#           'favourites_count': 5,
#           'follow_request_sent': False,
#           'followers_count': 18,
#           'following': True,
#           'friends_count': 35,
#           'geo_enabled': False,
#           'has_extended_profile': True,
#           'id': 40598976,
#           'id_str': '40598976',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 0,
#           'location': '',
#           'name': 'Ashish Nachane',
#           'notifications': False,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/40598976/1505523267',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'MonikerAsh',
#           'statuses_count': 77,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sun Jul 08 13:12:30 +0000 2018',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 150311026,
#                                  'id_str': '150311026',
#                                  'indices': [0, 10],
#                                  'name': 'محسن',
#                                  'screen_name': 'KingMo786'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1015946728749649920,
#  'id_str': '1015946728749649920',
#  'in_reply_to_screen_name': 'KingMo786',
#  'in_reply_to_status_id': 1015634554944671745,
#  'in_reply_to_status_id_str': '1015634554944671745',
#  'in_reply_to_user_id': 150311026,
#  'in_reply_to_user_id_str': '150311026',
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/iphone" '
#            'rel="nofollow">Twitter for iPhone</a>',
#  'text': '@KingMo786 That’s the British I know :)',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sun May 17 03:22:39 +0000 2009',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': 'I lead teams away from information hoarding on a '
#                          'path of data interpretation & analyitcs BIG Data '
#                          'style!',
#           'entities': {'description': {'urls': []}},
#           'favourites_count': 5,
#           'follow_request_sent': False,
#           'followers_count': 18,
#           'following': True,
#           'friends_count': 35,
#           'geo_enabled': False,
#           'has_extended_profile': True,
#           'id': 40598976,
#           'id_str': '40598976',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 0,
#           'location': '',
#           'name': 'Ashish Nachane',
#           'notifications': False,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/40598976/1505523267',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'MonikerAsh',
#           'statuses_count': 77,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sat Jun 23 17:30:20 +0000 2018',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 40598976,
#                                  'id_str': '40598976',
#                                  'indices': [10, 21],
#                                  'name': 'Ashish Nachane',
#                                  'screen_name': 'MonikerAsh'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1010575796031901696,
#  'id_str': '1010575796031901696',
#  'in_reply_to_screen_name': 'MonikerAsh',
#  'in_reply_to_status_id': 1010572372859084800,
#  'in_reply_to_status_id_str': '1010572372859084800',
#  'in_reply_to_user_id': 40598976,
#  'in_reply_to_user_id_str': '40598976',
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://pristineData.com" rel="nofollow">ashAppTweeter</a>',
#  'text': 'Thank you @MonikerAsh! Come again!',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sun May 17 03:22:39 +0000 2009',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': 'I lead teams away from information hoarding on a '
#                          'path of data interpretation & analyitcs BIG Data '
#                          'style!',
#           'entities': {'description': {'urls': []}},
#           'favourites_count': 5,
#           'follow_request_sent': False,
#           'followers_count': 18,
#           'following': True,
#           'friends_count': 35,
#           'geo_enabled': False,
#           'has_extended_profile': True,
#           'id': 40598976,
#           'id_str': '40598976',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 0,
#           'location': '',
#           'name': 'Ashish Nachane',
#           'notifications': False,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/40598976/1505523267',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'MonikerAsh',
#           'statuses_count': 77,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sat Jun 23 17:30:19 +0000 2018',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 1009237901073317888,
#                                  'id_str': '1009237901073317888',
#                                  'indices': [10, 18],
#                                  'name': 'MegNew',
#                                  'screen_name': 'MegNew2'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1010575794035396608,
#  'id_str': '1010575794035396608',
#  'in_reply_to_screen_name': 'MegNew2',
#  'in_reply_to_status_id': 1010572446230040576,
#  'in_reply_to_status_id_str': '1010572446230040576',
#  'in_reply_to_user_id': 1009237901073317888,
#  'in_reply_to_user_id_str': '1009237901073317888',
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://pristineData.com" rel="nofollow">ashAppTweeter</a>',
#  'text': 'Thank you @MegNew2! Come again!',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sun May 17 03:22:39 +0000 2009',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': 'I lead teams away from information hoarding on a '
#                          'path of data interpretation & analyitcs BIG Data '
#                          'style!',
#           'entities': {'description': {'urls': []}},
#           'favourites_count': 5,
#           'follow_request_sent': False,
#           'followers_count': 18,
#           'following': True,
#           'friends_count': 35,
#           'geo_enabled': False,
#           'has_extended_profile': True,
#           'id': 40598976,
#           'id_str': '40598976',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 0,
#           'location': '',
#           'name': 'Ashish Nachane',
#           'notifications': False,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/40598976/1505523267',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'MonikerAsh',
#           'statuses_count': 77,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sat Jun 23 17:30:19 +0000 2018',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 57237295,
#                                  'id_str': '57237295',
#                                  'indices': [10, 19],
#                                  'name': 'Riicha R Mohan',
#                                  'screen_name': 'Riicha_r'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1010575791929864192,
#  'id_str': '1010575791929864192',
#  'in_reply_to_screen_name': 'Riicha_r',
#  'in_reply_to_status_id': 1010572546130022401,
#  'in_reply_to_status_id_str': '1010572546130022401',
#  'in_reply_to_user_id': 57237295,
#  'in_reply_to_user_id_str': '57237295',
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://pristineData.com" rel="nofollow">ashAppTweeter</a>',
#  'text': 'Thank you @Riicha_r! Come again!',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sun May 17 03:22:39 +0000 2009',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': 'I lead teams away from information hoarding on a '
#                          'path of data interpretation & analyitcs BIG Data '
#                          'style!',
#           'entities': {'description': {'urls': []}},
#           'favourites_count': 5,
#           'follow_request_sent': False,
#           'followers_count': 18,
#           'following': True,
#           'friends_count': 35,
#           'geo_enabled': False,
#           'has_extended_profile': True,
#           'id': 40598976,
#           'id_str': '40598976',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 0,
#           'location': '',
#           'name': 'Ashish Nachane',
#           'notifications': False,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/40598976/1505523267',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'MonikerAsh',
#           'statuses_count': 77,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sat Jun 23 17:30:18 +0000 2018',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 363073498,
#                                  'id_str': '363073498',
#                                  'indices': [10, 25],
#                                  'name': 'Sivakumar V',
#                                  'screen_name': 'Satchithananda'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1010575790126354432,
#  'id_str': '1010575790126354432',
#  'in_reply_to_screen_name': 'Satchithananda',
#  'in_reply_to_status_id': 1010574894000730114,
#  'in_reply_to_status_id_str': '1010574894000730114',
#  'in_reply_to_user_id': 363073498,
#  'in_reply_to_user_id_str': '363073498',
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://pristineData.com" rel="nofollow">ashAppTweeter</a>',
#  'text': 'Thank you @Satchithananda! Come again!',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sun May 17 03:22:39 +0000 2009',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': 'I lead teams away from information hoarding on a '
#                          'path of data interpretation & analyitcs BIG Data '
#                          'style!',
#           'entities': {'description': {'urls': []}},
#           'favourites_count': 5,
#           'follow_request_sent': False,
#           'followers_count': 18,
#           'following': True,
#           'friends_count': 35,
#           'geo_enabled': False,
#           'has_extended_profile': True,
#           'id': 40598976,
#           'id_str': '40598976',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 0,
#           'location': '',
#           'name': 'Ashish Nachane',
#           'notifications': False,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/40598976/1505523267',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'MonikerAsh',
#           'statuses_count': 77,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sat Jun 23 17:30:18 +0000 2018',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 1009237802670870528,
#                                  'id_str': '1009237802670870528',
#                                  'indices': [10, 23],
#                                  'name': 'Deepa Karnani',
#                                  'screen_name': 'KarnaniDeepa'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1010575788540923904,
#  'id_str': '1010575788540923904',
#  'in_reply_to_screen_name': 'KarnaniDeepa',
#  'in_reply_to_status_id': 1010575685893664770,
#  'in_reply_to_status_id_str': '1010575685893664770',
#  'in_reply_to_user_id': 1009237802670870528,
#  'in_reply_to_user_id_str': '1009237802670870528',
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://pristineData.com" rel="nofollow">ashAppTweeter</a>',
#  'text': 'Thank you @KarnaniDeepa! Come again!',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sun May 17 03:22:39 +0000 2009',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': 'I lead teams away from information hoarding on a '
#                          'path of data interpretation & analyitcs BIG Data '
#                          'style!',
#           'entities': {'description': {'urls': []}},
#           'favourites_count': 5,
#           'follow_request_sent': False,
#           'followers_count': 18,
#           'following': True,
#           'friends_count': 35,
#           'geo_enabled': False,
#           'has_extended_profile': True,
#           'id': 40598976,
#           'id_str': '40598976',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 0,
#           'location': '',
#           'name': 'Ashish Nachane',
#           'notifications': False,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/40598976/1505523267',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'MonikerAsh',
#           'statuses_count': 77,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sat Jun 23 17:16:43 +0000 2018',
#  'entities': {'hashtags': [],
#               'symbols': [],
#               'urls': [],
#               'user_mentions': [{'id': 777278389,
#                                  'id_str': '777278389',
#                                  'indices': [0, 10],
#                                  'name': 'data student',
#                                  'screen_name': 'data_stew'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1010572372859084800,
#  'id_str': '1010572372859084800',
#  'in_reply_to_screen_name': 'data_stew',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': 777278389,
#  'in_reply_to_user_id_str': '777278389',
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#  'text': "@data_stew - are you looking for me? I am here team Let's get going",
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sun May 17 03:22:39 +0000 2009',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': 'I lead teams away from information hoarding on a '
#                          'path of data interpretation & analyitcs BIG Data '
#                          'style!',
#           'entities': {'description': {'urls': []}},
#           'favourites_count': 5,
#           'follow_request_sent': False,
#           'followers_count': 18,
#           'following': True,
#           'friends_count': 35,
#           'geo_enabled': False,
#           'has_extended_profile': True,
#           'id': 40598976,
#           'id_str': '40598976',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 0,
#           'location': '',
#           'name': 'Ashish Nachane',
#           'notifications': False,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/40598976/1505523267',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'MonikerAsh',
#           'statuses_count': 77,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sat Jun 23 16:55:37 +0000 2018',
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1010567062324903936,
#  'id_str': '1010567062324903936',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://pristineData.com" rel="nofollow">ashAppTweeter</a>',
#  'text': 'Weather for New York63.75 F',
#  'truncated': False,
# ...
#           'created_at': 'Sun May 17 03:22:39 +0000 2009',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': 'I lead teams away from information hoarding on a '
#                          'path of data interpretation & analyitcs BIG Data '
#                          'style!',
#           'entities': {'description': {'urls': []}},
#           'favourites_count': 5,
#           'follow_request_sent': False,
#           'followers_count': 18,
#           'following': True,
#           'friends_count': 35,
#           'geo_enabled': False,
#           'has_extended_profile': True,
#           'id': 40598976,
#           'id_str': '40598976',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 0,
#           'location': '',
#           'name': 'Ashish Nachane',
#           'notifications': False,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/40598976/1505523267',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'MonikerAsh',
#           'statuses_count': 77,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sat Jun 23 16:20:21 +0000 2018',
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1010558185286127618,
#  'id_str': '1010558185286127618',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://pristineData.com" rel="nofollow">ashAppTweeter</a>',
#  'text': 'The happiness of your life depends upon the quality of your '
#          'thoughts. - Marcus Aurelius',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sun May 17 03:22:39 +0000 2009',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': 'I lead teams away from information hoarding on a '
#                          'path of data interpretation & analyitcs BIG Data '
#                          'style!',
#           'entities': {'description': {'urls': []}},
#           'favourites_count': 5,
#           'follow_request_sent': False,
#           'followers_count': 18,
#           'following': True,
#           'friends_count': 35,
#           'geo_enabled': False,
#           'has_extended_profile': True,
#           'id': 40598976,
#           'id_str': '40598976',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 0,
#           'location': '',
#           'name': 'Ashish Nachane',
#           'notifications': False,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/40598976/1505523267',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'MonikerAsh',
#           'statuses_count': 77,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sat Jun 23 16:19:20 +0000 2018',
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1010557931597844483,
#  'id_str': '1010557931597844483',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://pristineData.com" rel="nofollow">ashAppTweeter</a>',
#  'text': 'Happiness is a warm puppy. - Charles M. Schulz',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sun May 17 03:22:39 +0000 2009',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': 'I lead teams away from information hoarding on a '
#                          'path of data interpretation & analyitcs BIG Data '
#                          'style!',
#           'entities': {'description': {'urls': []}},
#           'favourites_count': 5,
#           'follow_request_sent': False,
#           'followers_count': 18,
#           'following': True,
#           'friends_count': 35,
#           'geo_enabled': False,
#           'has_extended_profile': True,
#           'id': 40598976,
#           'id_str': '40598976',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 0,
#           'location': '',
#           'name': 'Ashish Nachane',
#           'notifications': False,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/40598976/1505523267',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'MonikerAsh',
#           'statuses_count': 77,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sat Jun 23 16:18:19 +0000 2018',
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1010557674197528577,
#  'id_str': '1010557674197528577',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://pristineData.com" rel="nofollow">ashAppTweeter</a>',
#  'text': 'Count your age by friends, not years. Count your life by smiles, not '
#          'tears. - John Lennon',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sun May 17 03:22:39 +0000 2009',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': 'I lead teams away from information hoarding on a '
#                          'path of data interpretation & analyitcs BIG Data '
#                          'style!',
#           'entities': {'description': {'urls': []}},
#           'favourites_count': 5,
#           'follow_request_sent': False,
#           'followers_count': 18,
#           'following': True,
#           'friends_count': 35,
#           'geo_enabled': False,
#           'has_extended_profile': True,
#           'id': 40598976,
#           'id_str': '40598976',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 0,
#           'location': '',
#           'name': 'Ashish Nachane',
#           'notifications': False,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/40598976/1505523267',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'MonikerAsh',
#           'statuses_count': 77,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sat Jun 23 16:17:18 +0000 2018',
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1010557417371897856,
#  'id_str': '1010557417371897856',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://pristineData.com" rel="nofollow">ashAppTweeter</a>',
#  'text': 'Happiness is when what you think, what you say, and what you do are '
#          'in harmony. - Mahatma Gandhi',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sun May 17 03:22:39 +0000 2009',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': 'I lead teams away from information hoarding on a '
#                          'path of data interpretation & analyitcs BIG Data '
#                          'style!',
#           'entities': {'description': {'urls': []}},
#           'favourites_count': 5,
#           'follow_request_sent': False,
#           'followers_count': 18,
#           'following': True,
#           'friends_count': 35,
#           'geo_enabled': False,
#           'has_extended_profile': True,
#           'id': 40598976,
#           'id_str': '40598976',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 0,
#           'location': '',
#           'name': 'Ashish Nachane',
#           'notifications': False,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/40598976/1505523267',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'MonikerAsh',
#           'statuses_count': 77,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': False}}
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sat Jun 23 16:16:15 +0000 2018',
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1010557156364517377,
#  'id_str': '1010557156364517377',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://pristineData.com" rel="nofollow">ashAppTweeter</a>',
#  'text': 'Folks are usually about as happy as they make their minds up to be. '
#          '- Abraham Lincoln',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#           'created_at': 'Sun May 17 03:22:39 +0000 2009',
#           'default_profile': True,
#           'default_profile_image': False,
#           'description': 'I lead teams away from information hoarding on a '
#                          'path of data interpretation & analyitcs BIG Data '
#                          'style!',
#           'entities': {'description': {'urls': []}},
#           'favourites_count': 5,
#           'follow_request_sent': False,
#           'followers_count': 18,
#           'following': True,
#           'friends_count': 35,
#           'geo_enabled': False,
#           'has_extended_profile': True,
#           'id': 40598976,
#           'id_str': '40598976',
#           'is_translation_enabled': False,
#           'is_translator': False,
#           'lang': 'en',
#           'listed_count': 0,
#           'location': '',
#           'name': 'Ashish Nachane',
#           'notifications': False,
#           'profile_background_color': 'C0DEED',
#           'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#           'profile_background_tile': False,
#           'profile_banner_url': 'https://pbs.twimg.com/profile_banners/40598976/1505523267',
#           'profile_image_url': 'http://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_image_url_https': 'https://pbs.twimg.com/profile_images/548435620520263681/xPoJhX1Z_normal.jpeg',
#           'profile_link_color': '1DA1F2',
#           'profile_sidebar_border_color': 'C0DEED',
#           'profile_sidebar_fill_color': 'DDEEF6',
#           'profile_text_color': '333333',
#           'profile_use_background_image': True,
#           'protected': False,
#           'screen_name': 'MonikerAsh',
#           'statuses_count': 77,
#           'time_zone': None,
#           'translator_type': 'none',
#           'url': None,
#           'utc_offset': None,
#           'verified': False}}
